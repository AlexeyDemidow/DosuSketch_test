# %%
from DrawingPlots import DrawingPlots

# %%
plots_and_paths = DrawingPlots()
plots_and_paths.draw_plots('https://ai-process-sandy.s3.eu-west-1.amazonaws.com/purge/deviation.json', 3)
# Out:
# ['plots/plot_corners.png',
#  'plots/plot_max.png',
#  'plots/plot_min.png',
#  'plots/plot_mean.png',
#  'plots/common.png',
#  'plots/ceiling.png',
#  'plots/floor.png']
